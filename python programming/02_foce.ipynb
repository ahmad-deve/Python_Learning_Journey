# %% [markdown]
# Integer in data typr

# %%
import requests
url = "https://theahmad.site/blog/"
response = requests.get(url) 
print(f"Status code: {response.status_code}")
print("content: ",response.text)
with open("index.html","w") as f:
    f.write(response.text)

# %%
a = 100
b = -12
c = 0
print("number 1:", a, type(a))
print("number 2:", b, type(c))
print("number 3:", c, type(b))

# %% [markdown]
# String in Data Type

# %%
 a = "Ahmad"
 b = """Ahmad is the good boy.He is very weak in study and love his computer and want to do something for his family and nothin to do else."""
 c = 'ali'
 print(a , type(a))
 print(b , type(b))
 print(c , type(c))
# Out:
# Ahmad <class 'str'>
# Ahmad is the good boy.He is very weak in study and love his computer and want to do something for his family and nothin to do else. <class 'str'>
# ali <class 'str'>

# %%
first_name = "Muhammad"  #Muhammad
last_name = "Ahamd"       #Ahmad
full_name = first_name + " " + last_name        #Muhammad Ahmad

haha = "ha" * 4 #hahahaha
now = a[0]      #A
now_1 = a[0:6]      #Ahmad

print("Full Name: " , full_name)
print("Mul: " , haha)
print("0 : " , now)
print("Full : " , now_1)
# Out:
# Full Name:  Muhammad Ahamd
# Mul:  hahahaha
# 0 :  A
# Full :  Ahmad

# %%
ag = int(input("Enter your age: "))
print(f"My age is {ag}.")

# %%
lis [0,4,5,1]
lis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lis [0,4,5,1]
#       2 lis()
#
# NameError: name 'lis' is not defined

# %%
import requests
url = "https://theahmad.site/blog/"
data = {
    "name":"ali",
    "age":  50
}
response = requests.post(url,data=data)
print(response.status_code)
print(response.text)
# Out:
# 404
# <!doctype html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
# 	<meta name='robots' content='noindex, follow' />
#
# 	<!-- This site is optimized with the Yoast SEO plugin v26.9 - https://yoast.com/product/yoast-seo-wordpress/ -->
# 	<title>Page not found - The Ahmad Site</title>
# 	<meta property="og:locale" content="en_US" />
# 	<meta property="og:title" content="Page not found - The Ahmad Site" />
# 	<meta property="og:site_name" content="The Ahmad Site" />
# ...
